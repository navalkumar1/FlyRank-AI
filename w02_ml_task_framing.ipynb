# %% [markdown]
# <a href="https://colab.research.google.com/github/navalkumar1/FlyRank-AI/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I am choosing Ranking as my ML task. Ranking is appropriate because the problem is about ordering pages by relevance and engagement, not just labeling or clustering them

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# I am choosing Ranking as my ML task. Ranking is appropriate because the problem is about ordering pages by relevance and engagement, not just labeling or clustering them

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I will use NDCG (Normalized Discounted Cumulative Gain) or, for simplicity at this stage, Mean Average Precision (MAP). These metrics measure how well the predicted ranking matches actual user engagement. A “good” score means the model places high‑CTR pages near the top.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/starter_dataset.csv")
df.head()

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule (e.g., “rank by impressions only”) misses complex patterns. Some pages have high impressions but low clicks, while others have fewer impressions but high CTR. ML can combine multiple signals (impressions, clicks, engagement) to learn nuanced ranking patterns that a simple rule cannot capture.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
